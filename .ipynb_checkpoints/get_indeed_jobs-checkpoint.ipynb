# %%
import requests
from bs4 import BeautifulSoup
import csv

# indeed의 url을 분석하여 limit와 url을 잘 조합한다.
LIMIT = 50 
URL = f"https://kr.indeed.com/jobs?q=python&limit={LIMIT}"

# 마지막 페이지를 알아낸다
def get_last_page():
    result = requests.get(URL)
    soup = BeautifulSoup(result.text, 'html.parser')
    pagination = soup.find("div",{"class": "pagination"})
    links = pagination.find_all("a")
    pages = []
    for link in links[:-1]:
        pages.append(int(link.find("span").string))    
    max_page = pages[-1]    
    return max_page


# extract_jobs에서 쓰이는 용도
# 하나의 페이지에서 반복되는 job의 정보를 추출
def extract_job(html):
    title = html.find("h2",{"class":"title"}).find("a")["title"]        
    company = html.find("span",{"class":"company"})
    if company:
        company_anchor = company.find("a")
        if company.find("a") is not None:
            company = (str(company_anchor.string))
        else:
            company = (str(company.string))        
        company = company.strip()    
    else:
        company: None
    location = html.find("div",{"class":"recJobLoc"})["data-rc-loc"]
    job_id = html["data-jk"]    
    return {"title": title, "company": company, "location":location ,"link":f"https://kr.indeed.com/viewjob?jk={job_id}"}
    

# 마지막페이지까지 반복하며 페이지마다 job의 정보를 모두 추출
def extract_jobs(last_page):    
    jobs=[]
    for page in range(last_page):
        print(f"scrapping page {page}")
        result = requests.get(f"{URL}&start={page*LIMIT}")
        soup = BeautifulSoup(result.text, 'html.parser')
        results = soup.find_all("div",{"class":"jobsearch-SerpJobCard"})
        for result in results:        
            job = extract_job(result)        
            jobs.append(job)
    return jobs

        
def get_jobs():    
    last_page = get_last_page()
#     너무 많이 뽑혀서 2번만 반복하게 만듭(2개의 페이지에서만 정보를 뽑아옴)
#     jobs = extract_jobs(last_page)    
    jobs = extract_jobs(2)    
    return  jobs



def save_to_file(jobs):
    file = open("indeed_jobs.csv", mode = "w", encoding = "utf-8") 
    writer = csv.writer(file)    
    writer.writerow(["title", "company", "location", "link"])
    for job in jobs:
        writer.writerow(list(job.values()))
    return jobs
save_to_file(get_jobs())
# Out:
# scrapping page 0
# scrapping page 1
# [{'title': '다나와 - 2020년 신입/경력직',
#   'company': '다나와',
#   'location': '서울 양천구',
#   'link': 'https://kr.indeed.com/viewjob?jk=ede0cb5f2ef3c702'},
#  {'title': '신입 매니저 (python, sketchup design tool 사용 가능자 우대)',
#   'company': 'PLA',
#   'location': '인천 연수구',
#   'link': 'https://kr.indeed.com/viewjob?jk=6bf7ac96cc93e2a1'},
#  {'title': 'Software Engineer',
#   'company': 'Google',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=857ae30c0bacaa35'},
#  {'title': '2021 Market Data Analyst - Seoul',
#   'company': 'Bloomberg',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=5b73d7ce16a8338a'},
#  {'title': '데이터 사이언티스트 (빅데이터/Python/R/데이터마이닝)',
#   'company': '이씨이십일알앤씨',
#   'location': '서울 강남구',
#   'link': 'https://kr.indeed.com/viewjob?jk=9b528300e8743fee'},
#  {'title': '[Ghent University Global Campus] Hiring Research Professors',
#   'company': '겐트대학교 글로벌캠퍼스',
#   'location': '인천 연수구',
#   'link': 'https://kr.indeed.com/viewjob?jk=bb8c019026aebec8'},
#  {'title': '2020 하반기 DB그룹 신입사원 공개 (예정)',
#   'company': 'DB그룹',
#   'location': '서울 강남구',
#   'link': 'https://kr.indeed.com/viewjob?jk=d1caddedfe1a1028'},
#  {'title': '[한국광기술원] 2020년 하반기 공개(~9/10)',
#   'company': '한국광기술원',
#   'location': '광주 북구',
#   'link': 'https://kr.indeed.com/viewjob?jk=8b9c3ab9b6ee6fc7'},
#  {'title': '[TmaxAI/R&D] AI본부 R&D 개발 연구원 신입/경력 (병역특례포함)',
#   'company': '티맥스소프트',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=c29a165fe861f7cb'},
#  {'title': '데이터마케팅 경력직',
#   'company': 'LG전자',
#   'location': '서울특별시',
#   'link': 'https://kr.indeed.com/viewjob?jk=5540c3a18b7d4b04'},
#  {'title': 'Support Engineer',
#   'company': 'Microsoft',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=0bbf23c0930be392'},
#  {'title': '연구소 개발부문 연구원 직원 (회로설계/하드웨어설계/머신비전/이미지프로세싱)',
#   'company': '모든',
#   'location': '경기도 광명',
#   'link': 'https://kr.indeed.com/viewjob?jk=79285cfc38abd6a0'},
#  {'title': '[취업연계 무료교육] 스마트제조 전문가 양성과정 훈련생',
#   'company': '한국산업기술협회',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=93a402e0da30e256'},
#  {'title': '[정보보안] 보안분석 플랫폼 개발 및 운영 담당자',
#   'company': '한국카카오은행',
#   'location': '성남 분당구',
#   'link': 'https://kr.indeed.com/viewjob?jk=2a094ace2f8604a7'},
#  {'title': 'Data Scientist',
#   'company': 'Boston Consulting Group',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=ce6747e77c861c46'},
#  {'title': '2020년도 제4차 계약직 공개',
#   'company': '한국광기술원',
#   'location': '광주 북구',
#   'link': 'https://kr.indeed.com/viewjob?jk=9487a1067f81ec10'},
#  {'title': '[피파온라인4] 테크니컬 아티스트',
#   'company': 'Electronic Arts',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=0bce5c7e8c1e521d'},
#  {'title': '[Autonomous Driving] Virtual Environment Simulation Engineer',
#   'company': '네이버',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=5ed0334bca0963cb'},
#  {'title': 'Junior Data Scientist',
#   'company': 'MSD',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=70b04d34ec7f6078'},
#  {'title': 'Developer / Designer recruit',
#   'company': '마이뮤직테이스트',
#   'location': '서울 논현동',
#   'link': 'https://kr.indeed.com/viewjob?jk=55a19c92c845685e'},
#  {'title': '하나손해보험 경력직',
#   'company': '하나손해보험',
#   'location': '서울 종로구',
#   'link': 'https://kr.indeed.com/viewjob?jk=0c07d097f996104e'},
#  {'title': '개발자 인턴십',
#   'company': '레이니스트',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=469c6f4eddd54a2c'},
#  {'title': 'Data Scientist',
#   'company': 'Koniag, Inc.',
#   'location': '대한민국',
#   'link': 'https://kr.indeed.com/viewjob?jk=193bfe67eed05c31'},
#  {'title': '보험 신규사업 비즈니스 분야 담당자 영입',
#   'company': '카카오페이',
#   'location': '성남 분당구',
#   'link': 'https://kr.indeed.com/viewjob?jk=e30f23f4f814b717'},
#  {'title': 'JR0142001 SW engineer intern',
#   'company': '인텔코리아',
#   'location': '서울 강남구',
#   'link': 'https://kr.indeed.com/viewjob?jk=f18e48dc201db10e'},
#  {'title': 'Applications Engineer (Library Characterization)',
#   'company': 'Synopsys',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=8c8700db243d1a3c'},
#  {'title': '신입 매니저 (python, sketchup design tool 사용 가능자 우대)',
#   'company': 'POLA',
#   'location': '인천 연수구',
#   'link': 'https://kr.indeed.com/viewjob?jk=432b32e90abb43a4'},
#  {'title': '현대오토에버 경력사원 대규모 상시',
#   'company': '현대오토에버',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=ba9770b7b17a038e'},
#  {'title': '머신러닝 개발',
#   'company': 'Nexon',
#   'location': '성남 분당구',
#   'link': 'https://kr.indeed.com/viewjob?jk=a1d687cd59776360'},
#  {'title': '[전문연구요원] 상시',
#   'company': '네이버',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=b79c2ae536063b01'},
#  {'title': '데이터분석 솔루션 개발자(python, Pandas)',
#   'company': '비아이매트릭스',
#   'location': '서울 강남구',
#   'link': 'https://kr.indeed.com/viewjob?jk=a7c2dadf012d2cda'},
#  {'title': '[외국계 스타트업 미소] Data Analyst',
#   'company': '유한회사 미소',
#   'location': '서울 성동구',
#   'link': 'https://kr.indeed.com/viewjob?jk=e1f5a3b0bd3eabfe'},
#  {'title': '[모두의기술] 딥러닝 엔지니어',
#   'company': '한국카카오은행',
#   'location': '성남 분당구',
#   'link': 'https://kr.indeed.com/viewjob?jk=2257e4f3d684ae2d'},
#  {'title': 'Quantitative Researcher(이공계전공 우수인재 영입)',
#   'company': '디에스파트너즈그룹',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=990f18f975068390'},
#  {'title': '2020년 각 부문 신입/경력',
#   'company': '더이앤엠',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=ee4d4d032c3e47c8'},
#  {'title': '[해외취업] 미국, Avellino, Data Analyst',
#   'company': 'Avellino Lab USA, Inc.',
#   'location': '대한민국',
#   'link': 'https://kr.indeed.com/viewjob?jk=f1aebd4ce425b71a'},
#  {'title': '카카오톡 보이스톡/페이스톡/라이브톡 개발자 모집',
#   'company': '카카오',
#   'location': '성남 판교역',
#   'link': 'https://kr.indeed.com/viewjob?jk=d585814d097935eb'},
#  {'title': 'Junior Full-stack Developer',
#   'company': 'Asiance',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=fb84164a9eed9423'},
#  {'title': '보훈대상자 인재 채용',
#   'company': '네오위즈',
#   'location': '대한민국',
#   'link': 'https://kr.indeed.com/viewjob?jk=dfcb86f156623e5c'},
#  {'title': '[NIT Service] NAVER IDC 서버 운영/관리(가산)',
#   'company': '엔아이티서비스',
#   'location': '서울 금천구',
#   'link': 'https://kr.indeed.com/viewjob?jk=ca49fb41a18feebf'},
#  {'title': '(화학대기업) IT기획',
#   'company': '화인크루',
#   'location': '성남 분당구',
#   'link': 'https://kr.indeed.com/viewjob?jk=af6b3d6fa634a77b'},
#  {'title': '데이터 분석가 모집',
#   'company': '카카오',
#   'location': '성남 판교역',
#   'link': 'https://kr.indeed.com/viewjob?jk=092d062a6faa7139'},
#  {'title': '[NIT Service] NAVER IDC 서버 운영/관리(평촌)',
#   'company': '엔아이티서비스',
#   'location': '안양 동안구',
#   'link': 'https://kr.indeed.com/viewjob?jk=ae71e1b4d34151eb'},
#  {'title': 'Technical Solutions Engineer',
#   'company': 'MightyHive',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=2d83dcf8baac736b'},
#  {'title': '[ 아이콘트롤스 ] 2020년 경력 직원 (데이터분석)',
#   'company': 'HDC아이콘트롤스',
#   'location': '성남 분당구',
#   'link': 'https://kr.indeed.com/viewjob?jk=8f65ee5238b477a2'},
#  {'title': 'MongoDB Engineer 모집',
#   'company': '카카오',
#   'location': '성남 판교역',
#   'link': 'https://kr.indeed.com/viewjob?jk=2695294aea6dc3b6'},
#  {'title': '[EY한영] 금융감사본부 Data Analytics 전문 경력직 모집',
#   'company': 'EY',
#   'location': '대한민국',
#   'link': 'https://kr.indeed.com/viewjob?jk=4207c3ceb2dad58c'},
#  {'title': '정보보안 담당자',
#   'company': 'Nexon',
#   'location': '성남 분당구',
#   'link': 'https://kr.indeed.com/viewjob?jk=eeb9fe1c361f0758'},
#  {'title': '데이터 분석가/사이언티스트(신입/경력)',
#   'company': '쏘카',
#   'location': '대한민국',
#   'link': 'https://kr.indeed.com/viewjob?jk=776a7ce9f625189d'},
#  {'title': 'Frontend Developer (Javascript/React)',
#   'company': 'Bepro Company',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=d11342cfe074df78'},
#  {'title': 'IT 개발 인력',
#   'company': '신한에이아이',
#   'location': '서울 영등포구',
#   'link': 'https://kr.indeed.com/viewjob?jk=5b7082e6fa4b1bde'},
#  {'title': '[Clova] Clova AI 인재',
#   'company': '네이버',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=92bd400e3b5306ba'},
#  {'title': 'AI/빅데이터/클라우드 분야 (인재 Pool)',
#   'company': 'LG유플러스',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=fb617eeb80ea6fa9'},
#  {'title': '기술 인턴 인공지능 응용 연구/개발 인턴',
#   'company': '써로마인드로보틱스',
#   'location': '서울 관악구',
#   'link': 'https://kr.indeed.com/viewjob?jk=71c47ac87bb4087e'},
#  {'title': '2020년 코난테크놀로지 하반기',
#   'company': '코난테크놀로지',
#   'location': '서울 서초구',
#   'link': 'https://kr.indeed.com/viewjob?jk=a02aec8af3bdd4b5'},
#  {'title': 'Python, Java, Backend 개발자',
#   'company': '이지메타',
#   'location': '서울 구로구',
#   'link': 'https://kr.indeed.com/viewjob?jk=c6160c26cd16dbcf'},
#  {'title': 'Security Engineer (모의해킹/취약점 점검)',
#   'company': 'Toss',
#   'location': '서울 강남구',
#   'link': 'https://kr.indeed.com/viewjob?jk=241ae1e7499c461c'},
#  {'title': '(대전) 국방 M&S 연구분석관(통계, 연구분석 등)',
#   'company': '심네트',
#   'location': '대전 유성구',
#   'link': 'https://kr.indeed.com/viewjob?jk=6676516c895ef85b'},
#  {'title': '[오디오플랫폼] Immersive Audio 기술 개발자',
#   'company': '네이버',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=afd325d078fb2c9f'},
#  {'title': 'SW engineer intern',
#   'company': 'Intel',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=ae042b7756b8eecd'},
#  {'title': 'Back-end Engineer (Python)',
#   'company': 'Soomgo',
#   'location': '서울 강남구',
#   'link': 'https://kr.indeed.com/viewjob?jk=752a4b5d63eac97c'},
#  {'title': '블록체인 시스템 엔지니어 채용(무관)',
#   'company': '네오위즈',
#   'location': '대한민국',
#   'link': 'https://kr.indeed.com/viewjob?jk=ef10a663799ced7d'},
#  {'title': '2020년 하반기 각 부문 신입/경력',
#   'company': '스탠드포인트',
#   'location': '서울 금천구',
#   'link': 'https://kr.indeed.com/viewjob?jk=158d61f253f65fb4'},
#  {'title': 'Deep Learning R&D Engineer',
#   'company': 'Intel',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=58613b11ebe8779c'},
#  {'title': 'Senior Deep Learning R&D Engineer',
#   'company': 'Intel',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=7ae9338822c0f0a0'},
#  {'title': '글로벌 여행 스타트업 Trazy - 백엔드 개발자 (Python)',
#   'company': '트레이지(Trazy)',
#   'location': '서울 중구',
#   'link': 'https://kr.indeed.com/viewjob?jk=7c3e870969914d57'},
#  {'title': '[카카오커머스] 기술직군',
#   'company': '카카오커머스',
#   'location': '성남 분당구',
#   'link': 'https://kr.indeed.com/viewjob?jk=665e5885dfd75df4'},
#  {'title': 'Software Engineer',
#   'company': 'Electronic Arts',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=1cf825d234463890'},
#  {'title': '[Clova] Cross Platform Python Packaging Intern',
#   'company': '네이버',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=85d495b911ccfb21'},
#  {'title': 'Data Analyst',
#   'company': '레이니스트',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=e5ca14de265f7fc9'},
#  {'title': '[Autonomous Driving] Virtual Environment Simulation Engineer',
#   'company': '네이버랩스',
#   'location': '경기도',
#   'link': 'https://kr.indeed.com/viewjob?jk=b2170ba059dd7f06'},
#  {'title': 'Junior Quant Trader',
#   'company': 'Byzantine Partners',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=25725b3c0e607311'},
#  {'title': 'NAVER IDC 서버 운영/관리(평촌)',
#   'company': 'NIT Service',
#   'location': '안양 동안구',
#   'link': 'https://kr.indeed.com/viewjob?jk=097c35ed002a62e5'},
#  {'title': '[해외취업] 베리텍, 시스템개발자/응용프로그래머',
#   'company': '에임하이글로벌',
#   'location': '대한민국',
#   'link': 'https://kr.indeed.com/viewjob?jk=3e2ccf374eae0c90'},
#  {'title': '[Robotics] Robot Software Engineer',
#   'company': '네이버랩스',
#   'location': '성남 분당구',
#   'link': 'https://kr.indeed.com/viewjob?jk=be6e2a1d722611c4'},
#  {'title': '[인재풀] 아티스트',
#   'company': 'Electronic Arts',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=aac8e9355cb855ac'},
#  {'title': '매칭 데이터분석',
#   'company': 'Nexon',
#   'location': '성남 분당구',
#   'link': 'https://kr.indeed.com/viewjob?jk=15edcadd124ad99a'},
#  {'title': '[취업연계교육]그린뉴딜분야 실무자 양성과정',
#   'company': '사단법인 한국벰스협회',
#   'location': '서울 구로구',
#   'link': 'https://kr.indeed.com/viewjob?jk=b40498e72bdbc8a1'},
#  {'title': '추천 시스템 소프트웨어 엔지니어',
#   'company': '카카오',
#   'location': '성남 판교역',
#   'link': 'https://kr.indeed.com/viewjob?jk=07375dc4e800dfa9'},
#  {'title': '[NAVERxLINE] Global Ad AI Engineer/AI Planner',
#   'company': '네이버',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=a358a39da5dfc360'},
#  {'title': '(화학대기업) IT기획(울산)',
#   'company': '화인크루',
#   'location': '울산',
#   'link': 'https://kr.indeed.com/viewjob?jk=5f223b3de4697fc3'},
#  {'title': 'NAVER, LINE 서비스 플랫폼 운영',
#   'company': 'NIT Service',
#   'location': '성남 삼평동',
#   'link': 'https://kr.indeed.com/viewjob?jk=285996f91e76a862'},
#  {'title': '[신입,경력] windows application 개발자',
#   'company': '유즈브레인넷',
#   'location': '서울 구로구',
#   'link': 'https://kr.indeed.com/viewjob?jk=2c0a31ef4221edfb'},
#  {'title': 'Data Analytics Specialist',
#   'company': 'Philip Morris International',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=05e5e5314b49e28f'},
#  {'title': '[아이콘트롤스] 2020년 경력 직원 (데이터분석)',
#   'company': '현대산업개발',
#   'location': '대한민국',
#   'link': 'https://kr.indeed.com/viewjob?jk=792d3ac05912a792'},
#  {'title': '[Forest] 네이버 쇼핑검색플랫폼 개발자',
#   'company': '네이버',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=f3a14b3f8d9e3e12'},
#  {'title': 'Data Analyst',
#   'company': 'Axiologic Solutions',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=eb45c08f4c4a43d8'},
#  {'title': 'IT Analyst, E-Commerce',
#   'company': 'Procter & Gamble',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=784cd549a392c126'},
#  {'title': 'RTL 및 ASIC 설계 엔지니어(딥러닝 하드웨어 프로세서 개발)',
#   'company': '딥엑스',
#   'location': '성남 분당구',
#   'link': 'https://kr.indeed.com/viewjob?jk=694ab958318e7fdc'},
#  {'title': '[기술기획] [인사/경영지원] 사내시스템 개발자',
#   'company': '한국카카오은행',
#   'location': '성남 분당구',
#   'link': 'https://kr.indeed.com/viewjob?jk=bd458282330f08cd'},
#  {'title': 'Developers',
#   'company': 'Coinplug',
#   'location': '경기도 성남',
#   'link': 'https://kr.indeed.com/viewjob?jk=9a9e91ae6092ed2d'},
#  {'title': '8퍼센트 개발자 (신입/경력)',
#   'company': '8퍼센트',
#   'location': '서울 종로구',
#   'link': 'https://kr.indeed.com/viewjob?jk=8af26b37623864c4'},
#  {'title': '[전문연구요원] 상시 (전직)',
#   'company': '네이버랩스',
#   'location': '경기도',
#   'link': 'https://kr.indeed.com/viewjob?jk=14b591547a3b9df5'},
#  {'title': '빅데이터, 인공지능(AI) 외 신입/경력 정규직',
#   'company': 'thecompany',
#   'location': '경상남도',
#   'link': 'https://kr.indeed.com/viewjob?jk=2b7bc67cebf49cc0'},
#  {'title': 'MySQL Engineer 모집',
#   'company': '카카오',
#   'location': '성남 판교역',
#   'link': 'https://kr.indeed.com/viewjob?jk=dd06066d79860614'},
#  {'title': '하드웨어, IoT 단말기 신입/경력 정규직',
#   'company': '디바이스넷',
#   'location': '안양 동안구',
#   'link': 'https://kr.indeed.com/viewjob?jk=b5bca9e34cc209c0'},
#  {'title': '[Search] [Vision] Computer Vision Engineer 체험형 인턴',
#   'company': '네이버',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=a41d35173ffe4666'},
#  {'title': 'Sr. Data Analyst-Web&Mobile 1',
#   'company': 'Amway Inc.',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=16bf97b777dbebcf'},
#  {'title': '추천 통계분석/데이터사이언티스트',
#   'company': '카카오',
#   'location': '성남 판교역',
#   'link': 'https://kr.indeed.com/viewjob?jk=bfe0f5ac4f32ec89'},
#  {'title': 'Frontend Developer (Javascript/React)',
#   'company': 'Bepro Company',
#   'location': '서울',
#   'link': 'https://kr.indeed.com/viewjob?jk=d11342cfe074df78'}]
