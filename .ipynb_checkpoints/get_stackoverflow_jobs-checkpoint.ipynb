# %%
import requests
from bs4 import BeautifulSoup
import csv

URL = f"https://stackoverflow.com/jobs?q=python"

def get_last_page():
    result = requests.get(URL)
    soup = BeautifulSoup(result.text, 'html.parser')
    pages = soup.find("div",{"class": "s-pagination"}).find_all("a")    
    last_pages = pages[-2].get_text(strip=True)
    return int(last_pages)



def extract_job(html):
    title = html.find("h2").find("a")["title"]    
    company_row = html.find("h3").find_all("span",recirsove=False)        
    company = company_row[0].get_text(strip=True)
    location = company_row[1].get_text(strip=True).strip("-").strip(" \r").strip("\n").strip("")
    job_id = html["data-jobid"]
    link = f"https://stackoverflow.com/jobs/{job_id}"    
    return {"title":title , "company":company,"location":location , "link":link}    
    

    
    
def extract_jobs(last_page):
    jobs=[]
    for page in range(last_page):
        print(f"scrapping SO: Page: {page+1}")        
        result = requests.get(f"{URL}&pg={page+1}")
        #         print(result.status_code)
        soup = BeautifulSoup(result.text, 'html.parser')
        results = soup.find_all("div",{"class":"-job"})        
        for result in results:
            job = extract_job(result)            
            jobs.append(job)
    return jobs
    
    
    
def get_jobs():
    last_page = get_last_page()    
#     너무 많이 뽑혀서 2번만 반복하게 만듭(2개의 페이지에서만 정보를 뽑아옴)
#     jobs = extract_jobs(last_page)
    jobs = extract_jobs(2)
    return jobs



def save_to_file(jobs):
    file = open("SO_jobs.csv", mode = "w", encoding = "utf-8") 
    writer = csv.writer(file)    
    writer.writerow(["title", "company", "location", "link"])
    for job in jobs:
        writer.writerow(list(job.values()))
    return jobs

save_to_file(get_jobs())
# Out:
# scrapping SO: Page: 1
# scrapping SO: Page: 2
# [{'title': 'Python Software Developer',
#   'company': 'Old Mission Capital, LLC',
#   'location': 'Chicago, IL',
#   'link': 'https://stackoverflow.com/jobs/237203'},
#  {'title': 'Python Developer',
#   'company': 'Ahex Technologies',
#   'location': 'Hyderabad, India',
#   'link': 'https://stackoverflow.com/jobs/431894'},
#  {'title': 'Senior Software Developer (Python-Django)',
#   'company': 'Skizzle Technolabs India Private Limited',
#   'location': 'Kochi, India',
#   'link': 'https://stackoverflow.com/jobs/427201'},
#  {'title': 'Software Developer Python',
#   'company': 'Husys',
#   'location': 'Hyderabad, India',
#   'link': 'https://stackoverflow.com/jobs/364529'},
#  {'title': 'Backend Developer – Python/Django',
#   'company': '5 Monkeys Agency AB',
#   'location': 'Göteborg, Sweden',
#   'link': 'https://stackoverflow.com/jobs/426940'},
#  {'title': 'Python Application Developer- London',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/431300'},
#  {'title': 'Senior Python Developer',
#   'company': 'Akshay Staffing and Recruitment Services',
#   'location': 'Hyderabad, India',
#   'link': 'https://stackoverflow.com/jobs/431903'},
#  {'title': 'Senior Software Engineer - Python',
#   'company': 'YouGov',
#   'location': 'Warsaw, Poland',
#   'link': 'https://stackoverflow.com/jobs/422635'},
#  {'title': 'Python Software Engineer',
#   'company': 'bloomon',
#   'location': 'Amsterdam, Netherlands',
#   'link': 'https://stackoverflow.com/jobs/286140'},
#  {'title': 'PYTHON DEVELOPER',
#   'company': 'Crashmeal',
#   'location': 'Hyderabad, India',
#   'link': 'https://stackoverflow.com/jobs/343506'},
#  {'title': 'Full Stack (Python/React) Software engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'New York, NY',
#   'link': 'https://stackoverflow.com/jobs/421440'},
#  {'title': 'Pythonエンジニア/システムインテグレータ・ソフトハウス',
#   'company': '株式会社 ゼロフィールド',
#   'location': 'Minato City, Japan',
#   'link': 'https://stackoverflow.com/jobs/402856'},
#  {'title': 'Senior python/django Developer',
#   'company': 'Div International Technology Services',
#   'location': 'Hyderabad, India',
#   'link': 'https://stackoverflow.com/jobs/431906'},
#  {'title': 'Python Developer',
#   'company': 'Sagarsoft India Limited',
#   'location': 'Hyderabad, India',
#   'link': 'https://stackoverflow.com/jobs/431909'},
#  {'title': 'Python Developer',
#   'company': 'De La Rue North America Holdings',
#   'location': 'Logan, UT',
#   'link': 'https://stackoverflow.com/jobs/431392'},
#  {'title': 'Python Developer',
#   'company': 'Promantra Synergy Solutions Ltd.',
#   'location': 'Hyderabad, India',
#   'link': 'https://stackoverflow.com/jobs/431907'},
#  {'title': 'Senior Backend Engineer - Python',
#   'company': 'APNATIME TECH PRIVATE LIMITED',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/411044'},
#  {'title': 'Django/Python Backend Engineer',
#   'company': 'PolicyFly',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/415347'},
#  {'title': 'Python Developer',
#   'company': 'YouGov',
#   'location': 'Bengaluru, India',
#   'link': 'https://stackoverflow.com/jobs/413507'},
#  {'title': 'Mid-Level Backend Software Engineer (Python / Django)',
#   'company': 'Tivix, Inc.',
#   'location': 'Wrocław, Poland',
#   'link': 'https://stackoverflow.com/jobs/420639'},
#  {'title': 'Python Developer/Senior Python Developer',
#   'company': 'Crebritech',
#   'location': 'Noida, India',
#   'link': 'https://stackoverflow.com/jobs/384512'},
#  {'title': 'Sr. Python Developer',
#   'company': 'Chakravuyha Software Technologies pvt Ltd',
#   'location': 'Hyderabad, India',
#   'link': 'https://stackoverflow.com/jobs/431902'},
#  {'title': 'Full Stack Developer - Python & Django',
#   'company': 'LiveHealth',
#   'location': 'Pune, India',
#   'link': 'https://stackoverflow.com/jobs/387071'},
#  {'title': 'Backend Software Engineer (Python or Java)',
#   'company': 'F-Secure',
#   'location': 'Helsinki, Finland',
#   'link': 'https://stackoverflow.com/jobs/430332'},
#  {'title': 'Python Developer',
#   'company': 'GeekyWorks',
#   'location': 'Pune, India',
#   'link': 'https://stackoverflow.com/jobs/408881'},
#  {'title': 'Backend Software Engineer (Python or Java)',
#   'company': 'F-Secure',
#   'location': 'Helsinki, Finland',
#   'link': 'https://stackoverflow.com/jobs/430332'},
#  {'title': 'Python Developer',
#   'company': 'GeekyWorks',
#   'location': 'Pune, India',
#   'link': 'https://stackoverflow.com/jobs/408881'},
#  {'title': 'Python Software Engineer - Glasgow - Associate',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Glasgow, UK',
#   'link': 'https://stackoverflow.com/jobs/427792'},
#  {'title': 'Python/Django Developer',
#   'company': 'GeekBull Consulting',
#   'location': 'Hyderabad, India',
#   'link': 'https://stackoverflow.com/jobs/431897'},
#  {'title': '(Senior) Full-Stack Software Engineer who loves Python',
#   'company': 'Advertima',
#   'location': 'Berlin, Germany',
#   'link': 'https://stackoverflow.com/jobs/422932'},
#  {'title': 'Mid-Senior Python / Django Engineer',
#   'company': 'Octopus Energy',
#   'location': 'Melbourne, Australia',
#   'link': 'https://stackoverflow.com/jobs/427558'},
#  {'title': 'Python/Django Developer',
#   'company': 'KGtoPG.com',
#   'location': 'Hyderabad, India',
#   'link': 'https://stackoverflow.com/jobs/431891'},
#  {'title': 'Backend Software Engineer (Python, Node.js)',
#   'company': 'F-Secure',
#   'location': 'Helsinki, Finland',
#   'link': 'https://stackoverflow.com/jobs/430333'},
#  {'title': 'Senior python/django Developer',
#   'company': 'Div International Technology Services',
#   'location': 'Hyderabad, India',
#   'link': 'https://stackoverflow.com/jobs/431906'},
#  {'title': 'Senior Python Back End Engineer (Remote-Brazil)',
#   'company': 'Loadsmart',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/430974'},
#  {'title': 'Python Full Stack Developer',
#   'company': 'GRK Technologies',
#   'location': 'Hyderabad, India',
#   'link': 'https://stackoverflow.com/jobs/426345'},
#  {'title': 'Python/Django Developer',
#   'company': 'Spiria Digital',
#   'location': 'Oakville, ON, Canada',
#   'link': 'https://stackoverflow.com/jobs/409892'},
#  {'title': 'Senior Backend Engineer - Python',
#   'company': 'APNATIME TECH PRIVATE LIMITED',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/411044'},
#  {'title': 'Django/Python Backend Engineer',
#   'company': 'PolicyFly',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/415347'},
#  {'title': 'Python Backend Developer / Data Engineer for Geo Applications',
#   'company': 'GAF AG',
#   'location': 'Neustrelitz, Deutschland',
#   'link': 'https://stackoverflow.com/jobs/419603'},
#  {'title': 'Sr. Python Developer',
#   'company': 'MBR Informatics',
#   'location': 'Hyderabad, India',
#   'link': 'https://stackoverflow.com/jobs/431899'},
#  {'title': 'Senior Python Engineer',
#   'company': 'Bulb Energy',
#   'location': 'London, UK',
#   'link': 'https://stackoverflow.com/jobs/396265'},
#  {'title': 'Python Developer/Senior Python Developer',
#   'company': 'Crebritech',
#   'location': 'Noida, India',
#   'link': 'https://stackoverflow.com/jobs/384512'},
#  {'title': 'Backend Developer – Python/Django',
#   'company': '5 Monkeys Agency AB',
#   'location': 'Stockholm, Sweden',
#   'link': 'https://stackoverflow.com/jobs/426938'},
#  {'title': 'Sr. Python Developer',
#   'company': 'Bombay Softwares',
#   'location': 'Ahmedabad, India',
#   'link': 'https://stackoverflow.com/jobs/427638'},
#  {'title': 'Python/ Flask Developer',
#   'company': 'Ibexlabs LLC',
#   'location': 'Hyderabad, India',
#   'link': 'https://stackoverflow.com/jobs/431892'},
#  {'title': 'Python Developer',
#   'company': 'Quarec Resources',
#   'location': 'Ahmedabad, India',
#   'link': 'https://stackoverflow.com/jobs/412138'},
#  {'title': 'Senior Python Developer',
#   'company': 'Lab Technologies SA',
#   'location': 'Chiasso, Switzerland',
#   'link': 'https://stackoverflow.com/jobs/331824'},
#  {'title': 'Backend Engineer - Python (m/f/d)',
#   'company': 'Laya Technologies',
#   'location': 'Munich, Germany',
#   'link': 'https://stackoverflow.com/jobs/333801'},
#  {'title': 'Python Developer/Bangalore',
#   'company': 'Talent Zone Consultants',
#   'location': 'Bengaluru, India',
#   'link': 'https://stackoverflow.com/jobs/413984'}]
